# %%
import pandas as pd
file_path = r'C:\Users\bharath\OneDrive\Desktop\IRIS.csv'
df = pd.read_csv(file_path)
print(df)
# Out:
#      OSM_ID  LONGITUDE  LATITUDE  ALTITUDE        CATEGORY  Unnamed: 5  \
# 0       5.1        3.5       1.4       0.2     Iris-setosa         NaN
# 1       4.9        3.0       1.4       0.2     Iris-setosa         NaN
# 2       4.7        3.2       1.3       0.2     Iris-setosa         NaN
# 3       4.6        3.1       1.5       0.2     Iris-setosa         NaN
# 4       5.0        3.6       1.4       0.2     Iris-setosa         NaN
# ..      ...        ...       ...       ...             ...         ...
# 145     6.7        3.0       5.2       2.3  Iris-virginica         NaN
# 146     6.3        2.5       5.0       1.9  Iris-virginica         NaN
# 147     6.5        3.0       5.2       2.0  Iris-virginica         NaN
# 148     6.2        3.4       5.4       2.3  Iris-virginica         NaN
# 149     5.9        3.0       5.1       1.8  Iris-virginica         NaN
#
#      Unnamed: 6
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...

# %%
head = df.head()
head
# Out:
#    OSM_ID  LONGITUDE  LATITUDE  ALTITUDE     CATEGORY  Unnamed: 5  Unnamed: 6
# 0     5.1        3.5       1.4       0.2  Iris-setosa         NaN         NaN
# 1     4.9        3.0       1.4       0.2  Iris-setosa         NaN         NaN
# 2     4.7        3.2       1.3       0.2  Iris-setosa         NaN         NaN
# 3     4.6        3.1       1.5       0.2  Iris-setosa         NaN         NaN
# 4     5.0        3.6       1.4       0.2  Iris-setosa         NaN         NaN

# %%
sorting = df.sort_values(by='OSM_ID')
sorting
# Out:
#      OSM_ID  LONGITUDE  LATITUDE  ALTITUDE        CATEGORY  Unnamed: 5  \
# 13      4.3        3.0       1.1       0.1     Iris-setosa         NaN
# 42      4.4        3.2       1.3       0.2     Iris-setosa         NaN
# 38      4.4        3.0       1.3       0.2     Iris-setosa         NaN
# 8       4.4        2.9       1.4       0.2     Iris-setosa         NaN
# 41      4.5        2.3       1.3       0.3     Iris-setosa         NaN
# ..      ...        ...       ...       ...             ...         ...
# 122     7.7        2.8       6.7       2.0  Iris-virginica         NaN
# 118     7.7        2.6       6.9       2.3  Iris-virginica         NaN
# 117     7.7        3.8       6.7       2.2  Iris-virginica         NaN
# 135     7.7        3.0       6.1       2.3  Iris-virginica         NaN
# 131     7.9        3.8       6.4       2.0  Iris-virginica         NaN
#
#      Unnamed: 6
# 13          NaN
# 42          NaN
# 38          NaN
# 8           NaN
# 41          NaN
# ...

# %%
column = df['OSM_ID']
column
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: OSM_ID, Length: 150, dtype: float64

# %%
aggregation = df.groupby('OSM_ID').agg('count')
aggregation
# Out:
#         LONGITUDE  LATITUDE  ALTITUDE  CATEGORY  Unnamed: 5  Unnamed: 6
# OSM_ID
# 4.3             1         1         1         1           0           0
# 4.4             3         3         3         3           0           0
# 4.5             1         1         1         1           0           0
# 4.6             4         4         4         4           0           0
# 4.7             2         2         2         2           0           0
# 4.8             5         5         5         5           0           0
# 4.9             6         6         6         6           0           0
# 5.0            10        10        10        10           0           0
# 5.1             9         9         9         9           0           0
# 5.2             4         4         4         4           0           0
# 5.3             1         1         1         1           0           0
# 5.4             6         6         6         6           0           0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = r'C:\Users\bharath\OneDrive\Desktop\IRIS.csv'
df = pd.read_csv(file_path)

category_counts = df['OSM_ID'].value_counts()

plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('OSM_ID')
plt.show()
