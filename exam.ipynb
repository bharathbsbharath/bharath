# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
data = load_breast_cancer()
X = data.data
y = data.target

# %%
rf_classifier = RandomForestClassifier(n_estimators=600, random_state=40)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=600, random_state=40)

# %%
y_pred = rf_classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
print(accuracy)
# Out:
# 0.9473684210526315

# %%
report = classification_report(y_test, y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92        39
#            1       0.97      0.95      0.96        75
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.95      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['precsion', 'recall', 'f1-score', 'support']
sizes = np.random.randint(1, 10, size=len(labels))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green', 'blue', 'yellow'])
plt.title('Simple Pie Chart')

plt.show()

# %%
import matplotlib.pyplot as plt
categories = ['precsion', 'recall', 'f1-score', 'support']
values = [0.90, 0.97, 0.94, 0.95]

plt.bar(categories, values, color='blue')

plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Graph Example')
plt.show()
